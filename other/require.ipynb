# %%
"libs":{
    "anyio": "3.6.1",
    "argon2-cffi": "21.3.0",
    "argon2-cffi-bindings": "21.2.0",
    "asttokens": "2.0.5",
    "attrs": "21.4.0",
    "backcall": "0.2.0",
    "beautifulsoup4": "4.11.1",
    "bleach": "5.0.0",
    "category-encoders": "2.4.1",
    "caugetch": "0.0.1",
    "cffi": "1.15.0",
    "clipboard": "0.0.4",
    "cloudpickle": "2.1.0",
    "colorama": "0.4.4",
    "cycler": "0.11.0",
    "Cython": "0.29.30",
    "debugpy": "1.6.0",
    "decorator": "5.1.1",
    "defusedxml": "0.7.1",
    "entrypoints": "0.4",
    "et-xmlfile": "1.1.0",
    "executing": "0.8.3",
    "fastjsonschema": "2.15.3",
    "fonttools": "4.33.3",
    "future": "0.18.2",
    "getpass4": "0.0.14.1",
    "greenlet": "1.1.2",
    "hdbcli": "2.12.25",
    "hyperopt": "0.2.7",
    "idna": "3.3",
    "importlib-resources": "5.7.1",
    "ipykernel": "6.13.0",
    "ipython": "8.4.0",
    "ipython-genutils": "0.2.0",
    "isort": "5.10.1",
    "jedi": "0.18.1",
    "Jinja2": "3.1.2",
    "joblib": "1.1.0",
    "jsonschema": "4.5.1",
    "jupyter-client": "7.3.1",
    "jupyter-contrib-core": "0.3.3",
    "jupyter-contrib-nbextensions": "0.5.1",
    "jupyter-core": "4.10.0",
    "jupyter-highlight-selected-word": "0.2.0",
    "jupyter-latex-envs": "1.4.6",
    "jupyter-nbextensions-configurator": "0.4.1",
    "jupyter-resource-usage": "0.6.1",
    "jupyter-server": "1.17.0",
    "jupyterlab-pygments": "0.2.2",
    "kiwisolver": "1.4.2",
    "lightgbm": "3.3.2",
    "lxml": "4.8.0",
    "MarkupSafe": "2.1.1",
    "matplotlib": "3.5.2",
    "matplotlib-inline": "0.1.3",
    "mistune": "0.8.4",
    "nbclient": "0.6.3",
    "nbconvert": "6.5.0",
    "nbformat": "5.4.0",
    "nest-asyncio": "1.5.5",
    "networkx": "2.8.2",
    "notebook": "6.4.11",
    "numpy": "1.22.4",
    "openpyxl": "3.0.10",
    "packaging": "21.3",
    "pandas": "1.4.2",
    "pandocfilters": "1.5.0",
    "parso": "0.8.3",
    "patsy": "0.5.2",
    "pexpect": "4.8.0",
    "pickleshare": "0.7.5",
    "Pillow": "9.1.1",
    "prometheus-client": "0.14.1",
    "prompt-toolkit": "3.0.29",
    "psutil": "5.9.1",
    "psycopg2-binary": "2.9.3",
    "ptyprocess": "0.7.0",
    "pure-eval": "0.2.2",
    "pure-sasl": "0.6.2",
    "py4j": "0.10.9.5",
    "pycparser": "2.21",
    "Pygments": "2.12.0",
    "PyHive": "0.6.5",
    "pyparsing": "3.0.9",
    "pyperclip": "1.8.2",
    "pyrsistent": "0.18.1",
    "pystan": "2.19.1.1",
    "python-dateutil": "2.8.2",
    "pytz": "2022.1",
    "PyYAML": "6.0",
    "pyzmq": "23.0.0",
    "sasl": "0.3.1",
    "scikit-learn": "1.1.1",
    "scipy": "1.8.1",
    "Send2Trash": "1.8.0",
    "simple-crypt": "4.1.7",
    "six": "1.16.0",
    "sniffio": "1.2.0",
    "soupsieve": "2.3.2.post1",
    "SQLAlchemy": "1.4.36",
    "sqlalchemy-hana": "0.5.0",
    "stack-data": "0.2.0",
    "statsmodels": "0.13.2",
    "terminado": "0.15.0",
    "threadpoolctl": "3.1.0",
    "thrift": "0.16.0",
    "thrift-sasl": "0.4.3",
    "tinycss2": "1.1.1",
    "tornado": "6.1",
    "tqdm": "4.64.0",
    "traitlets": "5.2.1.post0",
    "wcwidth": "0.2.5",
    "webencodings": "0.5.1",
    "websocket-client": "1.3.2",
    "xgboost": "1.6.1",
    "xlrd": "2.0.1",
    "XlsxWriter": "3.0.3",
    "zipp": "3.8.0",
    "optuna": "3.4.0",
    "seaborn": "0.13.0",
    "faiss-cpu": "1.7.4",
    "node2vec": "0.4.6",
    "gensim": "4.3.2",
    "catboost": ""
    }
},
"kernel":{
"env": {}
}

# %%
Get-Command python

python -m venv my_env
Remove-Item -Recurse -Force .\my_env

.\my_env\Scripts\Activate
deactivate

python --version # текущая версия питона
.\my_test_env\Scripts\python.exe -m pip install --upgrade pip #upgrade pip

pip list

pip freeze | % { pip uninstall -y $_} # скрутить виртуальное окружение до Дефолт

# %%
faiss-cpu==1.7.4  
pandas==1.4.2  
scikit-learn==1.1.1  
Flask==3.0.2

`causalml`

# %%
pip install -r requirements.txt
